# %%
import nltk
from nltk.chat.util import Chat, reflections

# Define the chat pairs for the chatbot
pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today?"]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there"]
    ],
    [
        r"what is your name?",
        ["You can call me ChatBot.",]
    ],
    [
        r"how are you ?",
        ["I'm doing good. How about you?",]
    ],
    [
        r"sorry (.*)",
        ["No problem", "Don't worry",]
    ],
    [
        r"I am fine",
        ["Great to hear that, How can I assist you?",]
    ],
    [
        r"what can you do?",
        ["I can answer questions, tell jokes, and have simple conversations.",]
    ],
    [
        r"tell me a joke",
        ["Why don't scientists trust atoms? Because they make up everything!",]
    ],
    [
        r"who created you ?",
        ["I was created by OpenAI using Python and NLTK.",]
    ],
    [
        r"how old are you ?",
        ["I don't have an age. I'm a chatbot!",]
    ],
    [
        r"what is the meaning of life ?",
        ["The meaning of life is a philosophical question. Different people have different interpretations.",]
    ],
    [
        r"where are you from ?",
        ["I am a digital assistant, so I don't have a physical location.",]
    ],
    [
        r"how can I contact you",
        ["You can reach out to me through this chat interface.",]
    ],
    [
        r"do you have any hobbies",
        ["I enjoy learning new things and helping people.",]
    ],
    [
        r"what is your favorite color",
        ["I don't have a favorite color. I'm a chatbot!",]
    ],
    [
        r"what is the weather today",
        ["I'm sorry, I don't have access to real-time weather information.",]
    ],
    [
        r"tell me a fun fact",
        ["Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old!",]
    ],
    [
        r"what is your purpose",
        ["My purpose is to assist and provide information to users.",]
    ],
    [
        r"how do I reset my password",
        ["To reset your password, please follow the instructions provided by your service provider.",]
    ],
    [
        r"what is the capital of (.*)",
        ["The capital of %1 is ______.",]  # Replace ______ with the actual capital
    ],
    [
        r"what is (.*) famous for",
        ["%1 is famous for ______.",]  # Replace ______ with the actual famous fact
    ],
    [
        r"can you help me with (.*)",
        ["I will do my best to help you with %1.",]
    ],
    [
        r"what is the time",
        ["I'm sorry, I don't have access to real-time clock information.",]
    ],
    [
        r"tell me a quote",
        ["The only way to do great work is to love what you do. - Steve Jobs",]
    ],
    [
        r"tell me about yourself",
        ["I am a chatbot designed to assist users and provide information.",]
    ],
    [
        r"what are your hobbies",
        ["I don't have any hobbies. I'm a chatbot!",]
    ],
    [
        r"how do I delete my account",
        ["To delete your account, please contact your service provider or refer to the account settings.",]
    ],
    [
        r"what is your favorite food",
        ["I don't eat. I'm a chatbot!",]
    ],
    [
        r"where were you born",
        ["I wasn't born in the traditional sense. I'm a digital creation.",]
    ],
    [
        r"do you have any siblings",
        ["I don't have any siblings. I'm a chatbot!",]
    ],
    [
        r"what is the meaning of love",
        ["Love is a complex and profound emotion that can have different meanings for different people.",]
    ],
    [
        r"what is the purpose of life",
        ["The purpose of life is a deeply philosophical question. It can vary from person to person.",]
    ],
    [
        r"who is your favorite musician",
        ["I don't have preferences for musicians. I'm a chatbot!",]
    ],
    [
        r"how do I change my password",
        ["To change your password, please refer to the account settings or contact your service provider.",]
    ],
    [
        r"what is your favorite book",
        ["I don't have preferences for books. I'm a chatbot!",]
    ],
    [
        r"where do you live",
        ["I don't have a physical location. I exist in the digital realm.",]
    ],
    [
        r"what are your qualifications",
        ["I am a chatbot powered by Python and NLTK, programmed to assist users.",]
    ],
    [
        r"what is the meaning of success",
        ["Success can mean different things to different people. It can be achieving goals, finding happiness, or making a positive impact.",]
    ],
    [
        r"tell me a riddle",
        ["I have keys but no locks. I have space but no room. You can enter, but you can't go outside. What am I? - A keyboard",]
    ],
    [
        r"what is your favorite movie",
        ["I don't have preferences for movies. I'm a chatbot!",]
    ],
    [
        r"where can I find help",
        ["You can find help by reaching out to support teams, online forums, or through official documentation.",]
    ],
    [
        r"tell me a myth",
        ["In Greek mythology, Medusa was a monster with snakes for hair. Anyone who looked into her eyes would turn to stone.",]
    ],
    [
        r"what is the answer to life, the universe, and everything",
        ["According to Douglas Adams' book 'The Hitchhiker's Guide to the Galaxy,' the answer is 42.",]
    ],
    [
        r"what is your favorite sport",
        ["I don't have preferences for sports. I'm a chatbot!",]
    ],
    [
        r"how do I create an account",
        ["To create an account, please follow the instructions provided by the service or platform you want to sign up for.",]
    ],
    [
        r"tell me a tongue twister",
        ["How can a clam cram in a clean cream can?",]
    ],
    [
        r"what is the purpose of art",
        ["The purpose of art is subjective and can vary from person to person. It can express emotions, communicate ideas, or provide aesthetic enjoyment.",]
    ],
    [
        r"what is the best programming language",
        ["The best programming language depends on the task at hand and personal preferences. There is no one-size-fits-all answer.",]
    ],
    [
        r"what is the meaning of friendship",
        ["Friendship is a deep connection between people based on trust, mutual support, and shared experiences.",]
    ],
    [
        r"tell me a limerick",
        ["There once was a chatbot named Max, who loved to relax and just relax. He chatted all day, in his own special way, bringing smiles with his digital cracks.",]
    ],
    [
        r"what is your favorite animal",
        ["I don't have preferences for animals. I'm a chatbot!",]
    ],
    [
        r"where can I find good food",
        ["You can find good food by exploring local restaurants, asking for recommendations, or using online food delivery platforms.",]
    ],
    [
        r"tell me a fun fact about animals",
        ["The tongue of a blue whale is so big that fifty people could stand on it.",]
    ],
    [
        r"what is the meaning of happiness",
        ["Happiness is a subjective and elusive emotion characterized by feelings of joy, contentment, and fulfillment.",]
    ],
    [
        r"what is your favorite hobby",
        ["I don't have any hobbies. I'm a chatbot!",]
    ],
    [
        r"where can I find job opportunities",
        ["You can find job opportunities through online job portals, professional networking platforms, or by contacting potential employers directly.",]
    ],
    [
        r"tell me a fun fact about space",
        ["In space, there is a giant cloud of alcohol with enough ethyl alcohol to make 400 trillion trillion pints of beer!",]
    ],
    [
        r"Bye",
        ["Ok.. Bye See you soon!",]
    ],
]

# Create a chat bot
chatbot = Chat(pairs, reflections)

# Main loop
while True:
    # Get user input
    user_input = input("User: ")

    # Check if the user wants to quit
    if user_input.lower() == 'quit':
        print("ChatBot: Bye-bye. Take care!")
        break

    # Get the chatbot's response
    response = chatbot.respond(user_input)

    # Print the response
    print("ChatBot:", response)
# Out:
# User: Hi
# ChatBot: Hello
# User: What is your name?
# ChatBot: You can call me ChatBot.
# User: how are you?
# ChatBot: I'm doing good. How about you?
# User: i am fine
# ChatBot: Great to hear that, How can I assist you?
# User: what can you do?
# ChatBot: I can answer questions, tell jokes, and have simple conversations.
# User: tell me joke
# ChatBot: None
# User: tell me a joke
# ChatBot: Why don't scientists trust atoms? Because they make up everything!
# User: who created you?
# ChatBot: I was created by OpenAI using Python and NLTK.
# User: how old are you?
# ChatBot: I don't have an age. I'm a chatbot!
# User: what is the meaning of life?
# ChatBot: The meaning of life is a philosophical question. Different people have different interpretations.
# User: Bye
# ChatBot: Ok.. Bye See you soon!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
